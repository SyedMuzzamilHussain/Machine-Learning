# %%
# Decision Tree ----- Supervised Machine Learning Model

# %%
# Two Types 
# 1. Decision Tree Classifier --- When we have target data categorical.
# 2. Decision Tree Regressor --- When we have target data numerical.

# %%
# Decision Tree Workiing

# Gini Index
# Changes in Entropy

# d.t = p1log1 - p2log2....pnlogn

# %% [raw]
# ✅ What is a Decision Tree?
#
# 🔹 Simple Definition:
# A Decision Tree is a machine learning algorithm that makes decisions by splitting data into branches, just like how we ask yes/no questions to reach a final answer.
# It looks like a tree where:
#
# Each node is a question (condition),
# Each branch is a possible answer (yes/no or true/false),
# Each leaf node is a final prediction (value or category).

# %% [raw]
# 📊 Example (Real-Life Style):
#
# Imagine you're predicting if a person will buy ice cream:
#
#             Is it hot?
#              /     \
#            Yes     No
#           /          \
#     Has money?      No buy
#       /   \
#    Yes   No
#   Buy   No Buy
#
# So the tree asks questions, and based on answers, it reaches a decision.

# %% [raw]
# 🎯 Where It's Used?
#
# | Problem Type   | Example                                   |
# | -------------- | ----------------------------------------- |
# | Classification | Spam or Not Spam, Yes/No, Disease/Healthy |
# | Regression     | Predicting price, age, temperature        |

# %% [raw]
# 🧠 How It Works?
# Start from root node (first question)
# Split data based on conditions (e.g., "Age > 30?")
# Keep splitting until data becomes:
# Pure (same class)
# Or max depth is reached
# It uses algorithms like:
#
# Gini Index or Entropy (for classification)
# MSE or MAE (for regression)

# %%
🔢 Classification Example:
Let’s say you want to predict whether a student will pass or fail based on:
Hours studied
Sleep hours
The decision tree may look like:

        Hours_Studied > 5?
          /           \
        Yes           No
       /               \
 Sleep > 6?           Fail
    /     \
  Pass    Fail

# %% [raw]
# 🔧 Types of Decision Trees:
#
# | Type                    | Use When                                    |
# | ----------------------- | ------------------------------------------- |
# | **Classification Tree** | Target is **categorical** (like Yes/No)     |
# | **Regression Tree**     | Target is **numerical** (like price or age) |
#
#
# 🔥 Advantages of Decision Tree:
# | Feature                   | Benefit                                        |
# | ------------------------- | ---------------------------------------------- |
# | Easy to understand        | Looks like flowchart                           |
# | No need for scaling       | Works without normalization or standardization |
# | Handles both types        | Works for classification & regression          |
# | Feature selection         | Automatically picks best features              |
# | Works with missing values | Can handle missing data (to some extent)       |
#
# ❌ Disadvantages:
# | Problem             | Description                                             |
# | ------------------- | ------------------------------------------------------- |
# | Overfitting         | Tree may learn too much (noise instead of pattern)      |
# | Unstable            | Small data change = big tree change                     |
# | Less accurate alone | Not always best accuracy (better with ensemble methods) |

# %%
🧠 How It Works?

# %%
import pandas as pd;
import numpy as np;

# %%
df = pd.read_csv("covid_toy.csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df['fever'] = si.fit_transform(df[['fever']])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['gender'] = lb.fit_transform(df[['gender']])
df['cough'] = lb.fit_transform(df[['cough']])
df['city'] = lb.fit_transform(df[['city']])
df['has_covid'] = lb.fit_transform(df[['has_covid']])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=dt, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5)

# %%
y_pred_2 = grid_search.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plot_tree(df, feature_names=x.columns, class_names=["No", "Yes"], filled=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[45], line 5
#       2 import matplotlib.pyplot as plt
#       4 plt.figure(figsize=(10, 5))
# ----> 5 plot_tree(df, feature_names=x.columns, class_names=["No", "Yes"], filled=True)
#       6 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:206, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     203 to_ignore += ["self", "cls"]
#     204 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 206 validate_parameter_constraints(
#     207     parameter_constraints, params, caller_name=func.__qualname__
#     208 )
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
# ...
