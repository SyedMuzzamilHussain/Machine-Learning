# %% [markdown]
# # Logistics Regression Model : When we have target column categorical.

# %% [raw]
# Discrete Data: Data that cannot be divided into smaller parts meaningfully — it comes in whole, countable units (e.g., 1, 2, 3 apples — not 2.5 apples).
#
# Continuous Data: Data that can be divided infinitely into smaller parts — it can take any value, including decimals (e.g., 2.5 kg, 3.75 meters).

# %% [raw]
# 🧠 Simple Definition:
# Logistic Regression is used when your target/output column is categorical (not numbers but classes or labels).
#
# It doesn’t give a number as output, but gives a probability between 0 and 1, and then converts it into a class (like Yes or No).

# %% [raw]
# 🎯 Example:
# Let’s say you want to predict if a person has diabetes based on their age and blood sugar.
#
# | Age | Blood Sugar | Diabetes |
# | --- | ----------- | -------- |
# | 30  | 110         | No       |
# | 45  | 160         | Yes      |
# | 35  | 140         | Yes      |
#
# Logistic Regression will learn from this and predict like:
#
# If Age = 40 and Blood Sugar = 150 → Probability of diabetes = 0.84 → So prediction = Yes
#
# 📈 How it works:
# It uses a special S-shaped curve (called Sigmoid function) to map predictions between 0 and 1.
#
# If output < 0.5 → Class 0 (e.g., No)
# If output ≥ 0.5 → Class 1 (e.g., Yes)
#
# 🔍 Where to Use Logistic Regression:
# Spam vs Not Spam
# Loan Approved vs Rejected
# Tumor: Malignant vs Benign
# Pass vs Fail
# Click Ad vs Not Click Ad

# %% [raw]
# ❓ If Logistic Regression is for classification,
# 🔹 Then why is it called "Regression"?
#
# Answer yet to found

# %%
# Backedn -  Activation Function  - Sigmoid -  Works on bases on probablity

# if 0.5 > value then return 1
# else return 0

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("covid_toy.csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df['fever'] = si.fit_transform(df[['fever']])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lr = LabelEncoder()

# %%
df['gender']=lr.fit_transform(df[['gender']])
df['cough']=lr.fit_transform(df[['cough']])
df['city']=lr.fit_transform(df[['city']])
df['has_covid']=lr.fit_transform(df[['has_covid']])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
x =df.drop(columns=['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
# When target data categorical then we use accuracy score

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
# Out:
# Confusion Matrix:
#  [[9 4]
#  [1 6]]

# %%
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.69      0.78        13
#            1       0.60      0.86      0.71         7
#
#     accuracy                           0.75        20
#    macro avg       0.75      0.77      0.74        20
# weighted avg       0.80      0.75      0.76        20
