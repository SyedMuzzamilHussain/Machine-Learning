# %% [markdown]
# ---
#
# ## 🧠 What is the Apriori Algorithm?
#
# **Apriori Algorithm** is a popular **unsupervised machine learning algorithm** used for **Association Rule Mining**.
# It helps **find relationships or patterns** between items in **large datasets**, like shopping data.
#
# ---
#
# ### 📦 Real-Life Example:
#
# Imagine you own a **supermarket**.
# You want to know:
#
# > "Which items are bought together by customers?"
#
# You find a pattern like:
#
# > **If a customer buys bread 🍞 and butter 🧈, they also buy milk 🥛.**
#
# This is what **Apriori** helps you find: such **frequent item combinations**.
#
# ---
#
# ### 🔍 How It Works (Step-by-Step):
#
# #### 1. **Frequent Itemsets**:
#
# It first finds all **frequent itemsets** (items bought together frequently).
#
# For example:
#
# * {Milk}
# * {Milk, Bread}
# * {Milk, Bread, Butter}
#
# It does this using a rule:
#
# > If an itemset is **infrequent**, then all its **larger combinations** will also be infrequent.
# > This helps reduce unnecessary calculations (this is called the **Apriori Principle**).
#
# #### 2. **Support**:
#
# Support = (How often an itemset appears) / (Total transactions)
#
# For example:
#
# * If 100 people shop and 20 buy {Milk, Bread}, the support is 20%.
#
# #### 3. **Confidence**:
#
# Confidence = (How often items are bought together) / (How often the base item is bought)
#
# Example:
#
# * Confidence of {Milk} → {Bread} =
#   (People who bought both Milk & Bread) / (People who bought Milk)
#
# #### 4. **Lift**:
#
# Lift = (Confidence) / (Expected Confidence if independent)
#
# If **Lift > 1**, then buying Milk **increases the chance** of buying Bread.
#
# ---
#
# ### 🛍️ Business Benefits:
#
# ✅ **Cross-selling**:
#
# > Suggest related items ("Customers who bought X also bought Y") – like Amazon or Flipkart.
#
# ✅ **Store Layout**:
#
# > Place frequently bought-together items closer (like chips and cold drinks).
#
# ✅ **Product Bundling**:
#
# > Create combo offers to increase sales (e.g., Pizza + Coke combo).
#
# ✅ **Inventory Management**:
#
# > Know which items are demanded together and stock accordingly.
#
# ---
#
# ### 💻 Where It’s Used:
#
# * E-commerce (Amazon, Flipkart)
# * Supermarkets (Big Bazaar, DMart)
# * Online streaming platforms (Netflix: people who watched X also watched Y)
#
# ---
#
# ### 🔧 Tools:
#
# You can implement the Apriori Algorithm using:
#
# * Python libraries like `mlxtend` and `apyori`
# * Dataset format: list of transactions (items bought together)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('market_basket.csv',header=None)

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
df.shape
# Out:
# (7501, 20)

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: apyori
#   Building wheel for apyori (pyproject.toml): started
#   Building wheel for apyori (pyproject.toml): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=6015 sha256=1b5ddcb1f70e12b9408c411640c7c17626f2bf778f310161dd082b9eb26e2495
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\4d\9f\d0\7ba4ae3f5de2f76ea362170ea0f157e6cc1d1b9aea188175f2
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
# Data Preprocessing
transactions = []
for i in range(0, 7501):
    transactions.append([str(df.values[i, j]) for j in range(0, 20)])

# Training the Apriori model
from apyori import apriori

rules = apriori(transactions, 
                min_support=0.003, 
                min_confidence=0.2, 
                min_lift=3, 
                min_length=2)

# Visualizing the result
results = list(rules)

# Extracting and displaying the results clearly
for i, item in enumerate(results):
    pair = item.items
    items = [x for x in pair]
    print(f"Rule #{i+1}: {items}")
    print(f"Support: {item.support}")
    for rule in item.ordered_statistics:
        print(f"  → {list(rule.items_base)} → {list(rule.items_add)}")
        print(f"  Confidence: {rule.confidence}")
        print(f"  Lift: {rule.lift}")
    print("--------------------------------------------------")
# Out:
# Rule #1: ['chicken', 'light cream']
# Support: 0.004532728969470737
#   → ['light cream'] → ['chicken']
#   Confidence: 0.29059829059829057
#   Lift: 4.84395061728395
# --------------------------------------------------
# Rule #2: ['escalope', 'mushroom cream sauce']
# Support: 0.005732568990801226
#   → ['mushroom cream sauce'] → ['escalope']
#   Confidence: 0.3006993006993007
#   Lift: 3.790832696715049
# --------------------------------------------------
# Rule #3: ['escalope', 'pasta']
# Support: 0.005865884548726837
#   → ['pasta'] → ['escalope']
#   Confidence: 0.3728813559322034
#   Lift: 4.700811850163794
# --------------------------------------------------
# Rule #4: ['honey', 'fromage blanc']
# Support: 0.003332888948140248
#   → ['fromage blanc'] → ['honey']
#   Confidence: 0.2450980392156863
#   Lift: 5.164270764485569
# --------------------------------------------------
# Rule #5: ['herb & pepper', 'ground beef']
# Support: 0.015997866951073192
#   → ['herb & pepper'] → ['ground beef']
#   Confidence: 0.3234501347708895
#   Lift: 3.2919938411349285
# --------------------------------------------------
# Rule #6: ['ground beef', 'tomato sauce']
# Support: 0.005332622317024397
#   → ['tomato sauce'] → ['ground beef']
#   Confidence: 0.3773584905660377
#   Lift: 3.840659481324083
# --------------------------------------------------
# Rule #7: ['light cream', 'olive oil']
# Support: 0.003199573390214638
#   → ['light cream'] → ['olive oil']
#   Confidence: 0.20512820512820515
#   Lift: 3.1147098515519573
# --------------------------------------------------
# Rule #8: ['whole wheat pasta', 'olive oil']
# Support: 0.007998933475536596
#   → ['whole wheat pasta'] → ['olive oil']
#   Confidence: 0.2714932126696833
#   Lift: 4.122410097642296
# --------------------------------------------------
# Rule #9: ['pasta', 'shrimp']
# Support: 0.005065991201173177
#   → ['pasta'] → ['shrimp']
#   Confidence: 0.3220338983050847
#   Lift: 4.506672147735896
# --------------------------------------------------
# Rule #10: ['spaghetti', 'milk', 'avocado']
# Support: 0.003332888948140248
#   → ['spaghetti', 'avocado'] → ['milk']
#   Confidence: 0.41666666666666663
#   Lift: 3.215449245541838
# --------------------------------------------------
# Rule #11: ['cake', 'milk', 'burgers']
# Support: 0.0037328356219170776
#   → ['milk', 'cake'] → ['burgers']
#   Confidence: 0.27999999999999997
#   Lift: 3.211437308868501
# --------------------------------------------------
# Rule #12: ['turkey', 'burgers', 'chocolate']
# Support: 0.0030662578322890282
#   → ['turkey', 'chocolate'] → ['burgers']
#   Confidence: 0.27058823529411763
#   Lift: 3.1034898363014927
# --------------------------------------------------
# Rule #13: ['turkey', 'milk', 'burgers']
# Support: 0.003199573390214638
#   → ['turkey', 'milk'] → ['burgers']
#   Confidence: 0.2823529411764706
#   Lift: 3.2384241770102533
# --------------------------------------------------
# Rule #14: ['frozen vegetables', 'cake', 'tomatoes']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'cake'] → ['tomatoes']
#   Confidence: 0.2987012987012987
#   Lift: 4.367560314928736
#   → ['cake', 'tomatoes'] → ['frozen vegetables']
#   Confidence: 0.36507936507936506
#   Lift: 3.8300144300144296
# --------------------------------------------------
# Rule #15: ['cereals', 'ground beef', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['cereals', 'ground beef'] → ['spaghetti']
#   Confidence: 0.6764705882352942
#   Lift: 3.8853031258445188
#   → ['cereals', 'spaghetti'] → ['ground beef']
#   Confidence: 0.45999999999999996
#   Lift: 4.681763907734057
# --------------------------------------------------
# Rule #16: ['chicken', 'milk', 'ground beef']
# Support: 0.0038661511798426876
#   → ['chicken', 'ground beef'] → ['milk']
#   Confidence: 0.40845070422535207
#   Lift: 3.152046020981858
# --------------------------------------------------
# Rule #17: ['chicken', 'nan', 'light cream']
# Support: 0.004532728969470737
#   → ['light cream'] → ['chicken', 'nan']
#   Confidence: 0.29059829059829057
#   Lift: 4.84395061728395
#   → ['light cream', 'nan'] → ['chicken']
#   Confidence: 0.29059829059829057
#   Lift: 4.84395061728395
# --------------------------------------------------
# Rule #18: ['chicken', 'milk', 'olive oil']
# Support: 0.0035995200639914677
#   → ['chicken', 'milk'] → ['olive oil']
#   Confidence: 0.24324324324324323
#   Lift: 3.693456614509246
#   → ['chicken', 'olive oil'] → ['milk']
#   Confidence: 0.5
#   Lift: 3.858539094650206
#   → ['milk', 'olive oil'] → ['chicken']
#   Confidence: 0.2109375
#   Lift: 3.51609375
# --------------------------------------------------
# Rule #19: ['chicken', 'olive oil', 'spaghetti']
# Support: 0.0034662045060658577
#   → ['chicken', 'spaghetti'] → ['olive oil']
#   Confidence: 0.20155038759689922
#   Lift: 3.0603835169318647
# --------------------------------------------------
# Rule #20: ['frozen vegetables', 'chocolate', 'shrimp']
# Support: 0.005332622317024397
#   → ['frozen vegetables', 'chocolate'] → ['shrimp']
#   Confidence: 0.23255813953488375
#   Lift: 3.2545123221103784
#   → ['chocolate', 'shrimp'] → ['frozen vegetables']
#   Confidence: 0.29629629629629634
#   Lift: 3.1084175084175087
# --------------------------------------------------
# Rule #21: ['chocolate', 'ground beef', 'herb & pepper']
# Support: 0.003999466737768298
#   → ['chocolate', 'herb & pepper'] → ['ground beef']
#   Confidence: 0.4411764705882354
#   Lift: 4.4901827759597746
# --------------------------------------------------
# Rule #22: ['soup', 'milk', 'chocolate']
# Support: 0.003999466737768298
#   → ['soup', 'chocolate'] → ['milk']
#   Confidence: 0.3947368421052632
#   Lift: 3.0462150747238472
# --------------------------------------------------
# Rule #23: ['cooking oil', 'ground beef', 'spaghetti']
# Support: 0.004799360085321957
#   → ['cooking oil', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5714285714285714
#   Lift: 3.2819951870487856
#   → ['cooking oil', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3025210084033613
#   Lift: 3.0789824749438446
# --------------------------------------------------
# Rule #24: ['eggs', 'herb & pepper', 'ground beef']
# Support: 0.0041327822956939075
#   → ['eggs', 'ground beef'] → ['herb & pepper']
#   Confidence: 0.2066666666666667
#   Lift: 4.178454627133872
#   → ['eggs', 'herb & pepper'] → ['ground beef']
#   Confidence: 0.3297872340425532
#   Lift: 3.3564912381997174
# --------------------------------------------------
# Rule #25: ['eggs', 'red wine', 'spaghetti']
# Support: 0.0037328356219170776
#   → ['eggs', 'red wine'] → ['spaghetti']
#   Confidence: 0.5283018867924528
#   Lift: 3.0342974370828397
# --------------------------------------------------
# Rule #26: ['escalope', 'mushroom cream sauce', 'nan']
# Support: 0.005732568990801226
#   → ['mushroom cream sauce'] → ['escalope', 'nan']
#   Confidence: 0.3006993006993007
#   Lift: 3.790832696715049
#   → ['mushroom cream sauce', 'nan'] → ['escalope']
#   Confidence: 0.3006993006993007
#   Lift: 3.790832696715049
# --------------------------------------------------
# Rule #27: ['escalope', 'nan', 'pasta']
# Support: 0.005865884548726837
#   → ['pasta'] → ['escalope', 'nan']
#   Confidence: 0.3728813559322034
#   Lift: 4.700811850163794
#   → ['pasta', 'nan'] → ['escalope']
#   Confidence: 0.3728813559322034
#   Lift: 4.700811850163794
# --------------------------------------------------
# Rule #28: ['french fries', 'herb & pepper', 'ground beef']
# Support: 0.003199573390214638
#   → ['french fries', 'ground beef'] → ['herb & pepper']
#   Confidence: 0.23076923076923078
#   Lift: 4.665768194070081
#   → ['french fries', 'herb & pepper'] → ['ground beef']
#   Confidence: 0.46153846153846156
#   Lift: 4.697421981004071
# --------------------------------------------------
# Rule #29: ['nan', 'honey', 'fromage blanc']
# Support: 0.003332888948140248
#   → ['fromage blanc'] → ['nan', 'honey']
#   Confidence: 0.2450980392156863
#   Lift: 5.1788180060756694
#   → ['nan', 'fromage blanc'] → ['honey']
#   Confidence: 0.2450980392156863
#   Lift: 5.164270764485569
# --------------------------------------------------
# Rule #30: ['frozen vegetables', 'tomatoes', 'green tea']
# Support: 0.003332888948140248
#   → ['frozen vegetables', 'green tea'] → ['tomatoes']
#   Confidence: 0.2314814814814815
#   Lift: 3.38468341635983
# --------------------------------------------------
# Rule #31: ['frozen vegetables', 'ground beef', 'spaghetti']
# Support: 0.008665511265164644
#   → ['frozen vegetables', 'spaghetti'] → ['ground beef']
#   Confidence: 0.31100478468899523
#   Lift: 3.165328208890303
# --------------------------------------------------
# Rule #32: ['frozen vegetables', 'milk', 'olive oil']
# Support: 0.004799360085321957
#   → ['frozen vegetables', 'milk'] → ['olive oil']
#   Confidence: 0.20338983050847456
#   Lift: 3.088314005352364
#   → ['frozen vegetables', 'olive oil'] → ['milk']
#   Confidence: 0.4235294117647058
#   Lift: 3.2684095860566447
# --------------------------------------------------
# Rule #33: ['frozen vegetables', 'soup', 'milk']
# Support: 0.003999466737768298
#   → ['frozen vegetables', 'soup'] → ['milk']
#   Confidence: 0.5
#   Lift: 3.858539094650206
# --------------------------------------------------
# Rule #34: ['frozen vegetables', 'milk', 'tomatoes']
# Support: 0.0041327822956939075
#   → ['milk', 'tomatoes'] → ['frozen vegetables']
#   Confidence: 0.29523809523809524
#   Lift: 3.0973160173160172
# --------------------------------------------------
# Rule #35: ['frozen vegetables', 'shrimp', 'mineral water']
# Support: 0.007199040127982935
#   → ['shrimp', 'mineral water'] → ['frozen vegetables']
#   Confidence: 0.30508474576271183
#   Lift: 3.200616332819722
# --------------------------------------------------
# Rule #36: ['frozen vegetables', 'olive oil', 'spaghetti']
# Support: 0.005732568990801226
#   → ['frozen vegetables', 'spaghetti'] → ['olive oil']
#   Confidence: 0.20574162679425836
#   Lift: 3.1240241752707125
# --------------------------------------------------
# Rule #37: ['frozen vegetables', 'shrimp', 'spaghetti']
# Support: 0.005999200106652446
#   → ['frozen vegetables', 'spaghetti'] → ['shrimp']
#   Confidence: 0.21531100478468898
#   Lift: 3.0131489680782684
# --------------------------------------------------
# Rule #38: ['frozen vegetables', 'shrimp', 'tomatoes']
# Support: 0.003999466737768298
#   → ['frozen vegetables', 'shrimp'] → ['tomatoes']
#   Confidence: 0.24000000000000002
#   Lift: 3.5092397660818717
#   → ['frozen vegetables', 'tomatoes'] → ['shrimp']
#   Confidence: 0.2479338842975207
#   Lift: 3.4696866905143704
#   → ['shrimp', 'tomatoes'] → ['frozen vegetables']
#   Confidence: 0.35714285714285715
#   Lift: 3.7467532467532467
# --------------------------------------------------
# Rule #39: ['frozen vegetables', 'tomatoes', 'spaghetti']
# Support: 0.006665777896280496
#   → ['frozen vegetables', 'spaghetti'] → ['tomatoes']
#   Confidence: 0.23923444976076558
#   Lift: 3.4980460188216425
#   → ['tomatoes', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.3184713375796179
#   Lift: 3.341053850607991
# --------------------------------------------------
# Rule #40: ['grated cheese', 'ground beef', 'spaghetti']
# Support: 0.005332622317024397
#   → ['grated cheese', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3225806451612903
#   Lift: 3.283144395325426
# --------------------------------------------------
# Rule #41: ['tomatoes', 'ground beef', 'green tea']
# Support: 0.0030662578322890282
#   → ['ground beef', 'green tea'] → ['tomatoes']
#   Confidence: 0.2072072072072072
#   Lift: 3.0297490472929067
# --------------------------------------------------
# Rule #42: ['milk', 'herb & pepper', 'ground beef']
# Support: 0.0035995200639914677
#   → ['milk', 'herb & pepper'] → ['ground beef']
#   Confidence: 0.3913043478260869
#   Lift: 3.9825968969382335
# --------------------------------------------------
# Rule #43: ['mineral water', 'herb & pepper', 'ground beef']
# Support: 0.006665777896280496
#   → ['herb & pepper', 'mineral water'] → ['ground beef']
#   Confidence: 0.39062500000000006
#   Lift: 3.975682666214383
# --------------------------------------------------
# Rule #44: ['nan', 'herb & pepper', 'ground beef']
# Support: 0.015997866951073192
#   → ['herb & pepper'] → ['nan', 'ground beef']
#   Confidence: 0.3234501347708895
#   Lift: 3.2919938411349285
#   → ['nan', 'herb & pepper'] → ['ground beef']
#   Confidence: 0.3234501347708895
#   Lift: 3.2919938411349285
# --------------------------------------------------
# Rule #45: ['herb & pepper', 'ground beef', 'spaghetti']
# Support: 0.006399146780429276
#   → ['herb & pepper', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3934426229508197
#   Lift: 4.004359721511667
# --------------------------------------------------
# Rule #46: ['milk', 'ground beef', 'olive oil']
# Support: 0.004932675643247567
#   → ['milk', 'ground beef'] → ['olive oil']
#   Confidence: 0.22424242424242427
#   Lift: 3.40494417862839
# --------------------------------------------------
# Rule #47: ['soup', 'milk', 'ground beef']
# Support: 0.003999466737768298
#   → ['soup', 'ground beef'] → ['milk']
#   Confidence: 0.4109589041095891
#   Lift: 3.1714019956029094
# --------------------------------------------------
# Rule #48: ['nan', 'ground beef', 'tomato sauce']
# Support: 0.005332622317024397
#   → ['tomato sauce'] → ['nan', 'ground beef']
#   Confidence: 0.3773584905660377
#   Lift: 3.840659481324083
#   → ['nan', 'tomato sauce'] → ['ground beef']
#   Confidence: 0.3773584905660377
#   Lift: 3.840659481324083
# --------------------------------------------------
# Rule #49: ['pepper', 'ground beef', 'spaghetti']
# Support: 0.003332888948140248
#   → ['pepper', 'spaghetti'] → ['ground beef']
#   Confidence: 0.33783783783783783
#   Lift: 3.4384282518610876
# --------------------------------------------------
# Rule #50: ['shrimp', 'ground beef', 'spaghetti']
# Support: 0.005999200106652446
#   → ['shrimp', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5232558139534884
#   Lift: 3.005315360233627
# --------------------------------------------------
# Rule #51: ['ground beef', 'tomato sauce', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['tomato sauce'] → ['ground beef', 'spaghetti']
#   Confidence: 0.2169811320754717
#   Lift: 5.535970992170453
#   → ['ground beef', 'tomato sauce'] → ['spaghetti']
#   Confidence: 0.5750000000000001
#   Lift: 3.3025076569678413
#   → ['tomato sauce', 'spaghetti'] → ['ground beef']
#   Confidence: 0.4893617021276596
#   Lift: 4.980599901844742
# --------------------------------------------------
# Rule #52: ['light cream', 'mineral water', 'spaghetti']
# Support: 0.003199573390214638
#   → ['light cream'] → ['mineral water', 'spaghetti']
#   Confidence: 0.20512820512820515
#   Lift: 3.4345238095238098
# --------------------------------------------------
# Rule #53: ['light cream', 'nan', 'olive oil']
# Support: 0.003199573390214638
#   → ['light cream'] → ['nan', 'olive oil']
#   Confidence: 0.20512820512820515
#   Lift: 3.121027721433401
#   → ['light cream', 'nan'] → ['olive oil']
#   Confidence: 0.20512820512820515
#   Lift: 3.1147098515519573
# --------------------------------------------------
# Rule #54: ['milk', 'shrimp', 'olive oil']
# Support: 0.003199573390214638
#   → ['shrimp', 'olive oil'] → ['milk']
#   Confidence: 0.3934426229508197
#   Lift: 3.0362274843149164
# --------------------------------------------------
# Rule #55: ['soup', 'milk', 'olive oil']
# Support: 0.0035995200639914677
#   → ['milk', 'olive oil'] → ['soup']
#   Confidence: 0.2109375
#   Lift: 4.174781497361478
#   → ['soup', 'milk'] → ['olive oil']
#   Confidence: 0.23684210526315788
#   Lift: 3.5962603878116344
#   → ['soup', 'olive oil'] → ['milk']
#   Confidence: 0.4029850746268656
#   Lift: 3.1098673300165833
# --------------------------------------------------
# Rule #56: ['milk', 'olive oil', 'spaghetti']
# Support: 0.007199040127982935
#   → ['milk', 'spaghetti'] → ['olive oil']
#   Confidence: 0.20300751879699247
#   Lift: 3.0825089038385434
# --------------------------------------------------
# Rule #57: ['soup', 'milk', 'tomatoes']
# Support: 0.0030662578322890282
#   → ['milk', 'tomatoes'] → ['soup']
#   Confidence: 0.21904761904761905
#   Lift: 4.335293378565146
#   → ['soup', 'tomatoes'] → ['milk']
#   Confidence: 0.44230769230769235
#   Lift: 3.4133230452674903
# --------------------------------------------------
# Rule #58: ['milk', 'whole wheat pasta', 'spaghetti']
# Support: 0.003999466737768298
#   → ['whole wheat pasta', 'spaghetti'] → ['milk']
#   Confidence: 0.4545454545454546
#   Lift: 3.5077628133183696
# --------------------------------------------------
# Rule #59: ['soup', 'mineral water', 'olive oil']
# Support: 0.005199306759098787
#   → ['soup', 'mineral water'] → ['olive oil']
#   Confidence: 0.22543352601156072
#   Lift: 3.4230301186492245
# --------------------------------------------------
# Rule #60: ['whole wheat pasta', 'mineral water', 'olive oil']
# Support: 0.0038661511798426876
#   → ['whole wheat pasta', 'mineral water'] → ['olive oil']
#   Confidence: 0.4027777777777778
#   Lift: 6.115862573099416
# --------------------------------------------------
# Rule #61: ['nan', 'whole wheat pasta', 'olive oil']
# Support: 0.007998933475536596
#   → ['whole wheat pasta'] → ['nan', 'olive oil']
#   Confidence: 0.2714932126696833
#   Lift: 4.13077198425009
#   → ['nan', 'whole wheat pasta'] → ['olive oil']
#   Confidence: 0.2714932126696833
#   Lift: 4.122410097642296
# --------------------------------------------------
# Rule #62: ['pasta', 'nan', 'shrimp']
# Support: 0.005065991201173177
#   → ['pasta'] → ['nan', 'shrimp']
#   Confidence: 0.3220338983050847
#   Lift: 4.515095833993347
#   → ['pasta', 'nan'] → ['shrimp']
#   Confidence: 0.3220338983050847
#   Lift: 4.506672147735896
# --------------------------------------------------
# Rule #63: ['pancakes', 'olive oil', 'spaghetti']
# Support: 0.005065991201173177
#   → ['pancakes', 'spaghetti'] → ['olive oil']
#   Confidence: 0.20105820105820105
#   Lift: 3.0529100529100526
# --------------------------------------------------
# Rule #64: ['tomatoes', 'olive oil', 'spaghetti']
# Support: 0.004399413411545127
#   → ['tomatoes', 'olive oil'] → ['spaghetti']
#   Confidence: 0.6111111111111112
#   Lift: 3.5099115194827295
#   → ['tomatoes', 'spaghetti'] → ['olive oil']
#   Confidence: 0.21019108280254778
#   Lift: 3.19158565202816
# --------------------------------------------------
# Rule #65: ['tomatoes', 'whole wheat rice', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['whole wheat rice', 'spaghetti'] → ['tomatoes']
#   Confidence: 0.2169811320754717
#   Lift: 3.1726617382029496
# --------------------------------------------------
# Rule #66: ['spaghetti', 'milk', 'nan', 'avocado']
# Support: 0.003332888948140248
#   → ['spaghetti', 'avocado'] → ['milk', 'nan']
#   Confidence: 0.41666666666666663
#   Lift: 3.215449245541838
#   → ['spaghetti', 'nan', 'avocado'] → ['milk']
#   Confidence: 0.41666666666666663
#   Lift: 3.215449245541838
# --------------------------------------------------
# Rule #67: ['cake', 'milk', 'burgers', 'nan']
# Support: 0.0037328356219170776
#   → ['milk', 'cake'] → ['nan', 'burgers']
#   Confidence: 0.27999999999999997
#   Lift: 3.211437308868501
#   → ['milk', 'cake', 'nan'] → ['burgers']
#   Confidence: 0.27999999999999997
#   Lift: 3.211437308868501
# --------------------------------------------------
# Rule #68: ['turkey', 'nan', 'burgers', 'chocolate']
# Support: 0.0030662578322890282
#   → ['turkey', 'chocolate'] → ['nan', 'burgers']
#   Confidence: 0.27058823529411763
#   Lift: 3.1034898363014927
#   → ['turkey', 'nan', 'chocolate'] → ['burgers']
#   Confidence: 0.27058823529411763
#   Lift: 3.1034898363014927
# --------------------------------------------------
# Rule #69: ['turkey', 'milk', 'burgers', 'nan']
# Support: 0.003199573390214638
#   → ['turkey', 'milk'] → ['nan', 'burgers']
#   Confidence: 0.2823529411764706
#   Lift: 3.2384241770102533
#   → ['turkey', 'milk', 'nan'] → ['burgers']
#   Confidence: 0.2823529411764706
#   Lift: 3.2384241770102533
# --------------------------------------------------
# Rule #70: ['frozen vegetables', 'nan', 'cake', 'tomatoes']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'cake'] → ['nan', 'tomatoes']
#   Confidence: 0.2987012987012987
#   Lift: 4.367560314928736
#   → ['cake', 'tomatoes'] → ['frozen vegetables', 'nan']
#   Confidence: 0.36507936507936506
#   Lift: 3.8300144300144296
#   → ['frozen vegetables', 'nan', 'cake'] → ['tomatoes']
#   Confidence: 0.2987012987012987
#   Lift: 4.367560314928736
#   → ['nan', 'cake', 'tomatoes'] → ['frozen vegetables']
#   Confidence: 0.36507936507936506
#   Lift: 3.8300144300144296
# --------------------------------------------------
# Rule #71: ['cereals', 'nan', 'ground beef', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['cereals', 'ground beef'] → ['nan', 'spaghetti']
#   Confidence: 0.6764705882352942
#   Lift: 3.8853031258445188
#   → ['cereals', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.45999999999999996
#   Lift: 4.681763907734057
#   → ['cereals', 'nan', 'ground beef'] → ['spaghetti']
#   Confidence: 0.6764705882352942
#   Lift: 3.8853031258445188
#   → ['cereals', 'nan', 'spaghetti'] → ['ground beef']
#   Confidence: 0.45999999999999996
#   Lift: 4.681763907734057
# --------------------------------------------------
# Rule #72: ['chicken', 'milk', 'nan', 'ground beef']
# Support: 0.0038661511798426876
#   → ['chicken', 'ground beef'] → ['milk', 'nan']
#   Confidence: 0.40845070422535207
#   Lift: 3.152046020981858
#   → ['chicken', 'nan', 'ground beef'] → ['milk']
#   Confidence: 0.40845070422535207
#   Lift: 3.152046020981858
# --------------------------------------------------
# Rule #73: ['chicken', 'milk', 'nan', 'olive oil']
# Support: 0.0035995200639914677
#   → ['chicken', 'milk'] → ['nan', 'olive oil']
#   Confidence: 0.24324324324324323
#   Lift: 3.700948412915958
#   → ['chicken', 'olive oil'] → ['milk', 'nan']
#   Confidence: 0.5
#   Lift: 3.858539094650206
#   → ['milk', 'olive oil'] → ['chicken', 'nan']
#   Confidence: 0.2109375
#   Lift: 3.51609375
#   → ['chicken', 'milk', 'nan'] → ['olive oil']
#   Confidence: 0.24324324324324323
#   Lift: 3.693456614509246
#   → ['chicken', 'nan', 'olive oil'] → ['milk']
#   Confidence: 0.5
#   Lift: 3.858539094650206
#   → ['milk', 'nan', 'olive oil'] → ['chicken']
#   Confidence: 0.2109375
#   Lift: 3.51609375
# --------------------------------------------------
# Rule #74: ['chicken', 'nan', 'olive oil', 'spaghetti']
# Support: 0.0034662045060658577
#   → ['chicken', 'spaghetti'] → ['nan', 'olive oil']
#   Confidence: 0.20155038759689922
#   Lift: 3.0665911914083996
#   → ['chicken', 'nan', 'spaghetti'] → ['olive oil']
#   Confidence: 0.20155038759689922
#   Lift: 3.0603835169318647
# --------------------------------------------------
# Rule #75: ['eggs', 'mineral water', 'chocolate', 'ground beef']
# Support: 0.003999466737768298
#   → ['eggs', 'ground beef'] → ['chocolate', 'mineral water']
#   Confidence: 0.20000000000000004
#   Lift: 3.7979746835443047
#   → ['eggs', 'chocolate', 'mineral water'] → ['ground beef']
#   Confidence: 0.29702970297029707
#   Lift: 3.023093354111531
# --------------------------------------------------
# Rule #76: ['frozen vegetables', 'mineral water', 'chocolate', 'ground beef']
# Support: 0.003332888948140248
#   → ['frozen vegetables', 'chocolate', 'mineral water'] → ['ground beef']
#   Confidence: 0.34246575342465757
#   Lift: 3.4855300087358976
#   → ['mineral water', 'chocolate', 'ground beef'] → ['frozen vegetables']
#   Confidence: 0.30487804878048785
#   Lift: 3.1984478935698455
# --------------------------------------------------
# Rule #77: ['frozen vegetables', 'chocolate', 'ground beef', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'chocolate', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5348837209302326
#   Lift: 3.0721001460165964
#   → ['frozen vegetables', 'chocolate', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3898305084745763
#   Lift: 3.967596531978015
#   → ['chocolate', 'ground beef', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.33333333333333337
#   Lift: 3.4969696969696975
# --------------------------------------------------
# Rule #78: ['frozen vegetables', 'milk', 'chocolate', 'mineral water']
# Support: 0.003999466737768298
#   → ['frozen vegetables', 'chocolate', 'mineral water'] → ['milk']
#   Confidence: 0.4109589041095891
#   Lift: 3.1714019956029094
# --------------------------------------------------
# Rule #79: ['frozen vegetables', 'milk', 'chocolate', 'spaghetti']
# Support: 0.0034662045060658577
#   → ['frozen vegetables', 'chocolate', 'spaghetti'] → ['milk']
#   Confidence: 0.44067796610169485
#   Lift: 3.4007463207086555
#   → ['milk', 'chocolate', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.3170731707317073
#   Lift: 3.3263858093126384
# --------------------------------------------------
# Rule #80: ['frozen vegetables', 'chocolate', 'mineral water', 'shrimp']
# Support: 0.003199573390214638
#   → ['frozen vegetables', 'chocolate', 'mineral water'] → ['shrimp']
#   Confidence: 0.32876712328767127
#   Lift: 4.600899611531385
#   → ['chocolate', 'mineral water', 'shrimp'] → ['frozen vegetables']
#   Confidence: 0.4210526315789474
#   Lift: 4.417224880382776
# --------------------------------------------------
# Rule #81: ['frozen vegetables', 'nan', 'chocolate', 'shrimp']
# Support: 0.005332622317024397
#   → ['frozen vegetables', 'chocolate'] → ['nan', 'shrimp']
#   Confidence: 0.23255813953488375
#   Lift: 3.260595522712454
#   → ['chocolate', 'shrimp'] → ['frozen vegetables', 'nan']
#   Confidence: 0.29629629629629634
#   Lift: 3.1084175084175087
#   → ['frozen vegetables', 'nan', 'chocolate'] → ['shrimp']
#   Confidence: 0.23255813953488375
#   Lift: 3.2545123221103784
#   → ['nan', 'chocolate', 'shrimp'] → ['frozen vegetables']
#   Confidence: 0.29629629629629634
#   Lift: 3.1084175084175087
# --------------------------------------------------
# Rule #82: ['nan', 'chocolate', 'ground beef', 'herb & pepper']
# Support: 0.003999466737768298
#   → ['chocolate', 'herb & pepper'] → ['nan', 'ground beef']
#   Confidence: 0.4411764705882354
#   Lift: 4.4901827759597746
#   → ['nan', 'chocolate', 'herb & pepper'] → ['ground beef']
#   Confidence: 0.4411764705882354
#   Lift: 4.4901827759597746
# --------------------------------------------------
# Rule #83: ['soup', 'milk', 'chocolate', 'nan']
# Support: 0.003999466737768298
#   → ['soup', 'chocolate'] → ['milk', 'nan']
#   Confidence: 0.3947368421052632
#   Lift: 3.0462150747238472
#   → ['soup', 'nan', 'chocolate'] → ['milk']
#   Confidence: 0.3947368421052632
#   Lift: 3.0462150747238472
# --------------------------------------------------
# Rule #84: ['chocolate', 'mineral water', 'olive oil', 'spaghetti']
# Support: 0.0038661511798426876
#   → ['chocolate', 'olive oil'] → ['mineral water', 'spaghetti']
#   Confidence: 0.23577235772357724
#   Lift: 3.947608159117306
#   → ['chocolate', 'mineral water', 'spaghetti'] → ['olive oil']
#   Confidence: 0.2436974789915966
#   Lift: 3.700353825740822
# --------------------------------------------------
# Rule #85: ['chocolate', 'mineral water', 'shrimp', 'spaghetti']
# Support: 0.0034662045060658577
#   → ['chocolate', 'mineral water', 'spaghetti'] → ['shrimp']
#   Confidence: 0.21848739495798317
#   Lift: 3.0576006522011783
# --------------------------------------------------
# Rule #86: ['cooking oil', 'nan', 'ground beef', 'spaghetti']
# Support: 0.004799360085321957
#   → ['cooking oil', 'ground beef'] → ['nan', 'spaghetti']
#   Confidence: 0.5714285714285714
#   Lift: 3.2819951870487856
#   → ['cooking oil', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.3025210084033613
#   Lift: 3.0789824749438446
#   → ['cooking oil', 'nan', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5714285714285714
#   Lift: 3.2819951870487856
#   → ['cooking oil', 'nan', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3025210084033613
#   Lift: 3.0789824749438446
# --------------------------------------------------
# Rule #87: ['eggs', 'frozen vegetables', 'milk', 'mineral water']
# Support: 0.0037328356219170776
#   → ['eggs', 'frozen vegetables', 'mineral water'] → ['milk']
#   Confidence: 0.411764705882353
#   Lift: 3.177620430888405
# --------------------------------------------------
# Rule #88: ['eggs', 'nan', 'herb & pepper', 'ground beef']
# Support: 0.0041327822956939075
#   → ['eggs', 'ground beef'] → ['nan', 'herb & pepper']
#   Confidence: 0.2066666666666667
#   Lift: 4.178454627133872
#   → ['eggs', 'herb & pepper'] → ['nan', 'ground beef']
#   Confidence: 0.3297872340425532
#   Lift: 3.3564912381997174
#   → ['eggs', 'nan', 'ground beef'] → ['herb & pepper']
#   Confidence: 0.2066666666666667
#   Lift: 4.178454627133872
#   → ['eggs', 'nan', 'herb & pepper'] → ['ground beef']
#   Confidence: 0.3297872340425532
#   Lift: 3.3564912381997174
# --------------------------------------------------
# Rule #89: ['eggs', 'red wine', 'nan', 'spaghetti']
# Support: 0.0037328356219170776
#   → ['eggs', 'red wine'] → ['nan', 'spaghetti']
#   Confidence: 0.5283018867924528
#   Lift: 3.0342974370828397
#   → ['eggs', 'red wine', 'nan'] → ['spaghetti']
#   Confidence: 0.5283018867924528
#   Lift: 3.0342974370828397
# --------------------------------------------------
# Rule #90: ['nan', 'french fries', 'herb & pepper', 'ground beef']
# Support: 0.003199573390214638
#   → ['french fries', 'ground beef'] → ['nan', 'herb & pepper']
#   Confidence: 0.23076923076923078
#   Lift: 4.665768194070081
#   → ['french fries', 'herb & pepper'] → ['nan', 'ground beef']
#   Confidence: 0.46153846153846156
#   Lift: 4.697421981004071
#   → ['french fries', 'nan', 'ground beef'] → ['herb & pepper']
#   Confidence: 0.23076923076923078
#   Lift: 4.665768194070081
#   → ['french fries', 'herb & pepper', 'nan'] → ['ground beef']
#   Confidence: 0.46153846153846156
#   Lift: 4.697421981004071
# --------------------------------------------------
# Rule #91: ['milk', 'frozen smoothie', 'mineral water', 'spaghetti']
# Support: 0.003199573390214638
#   → ['milk', 'frozen smoothie'] → ['mineral water', 'spaghetti']
#   Confidence: 0.22429906542056074
#   Lift: 3.7555073431241657
#   → ['frozen smoothie', 'spaghetti'] → ['milk', 'mineral water']
#   Confidence: 0.20512820512820515
#   Lift: 4.274074074074075
#   → ['frozen smoothie', 'mineral water', 'spaghetti'] → ['milk']
#   Confidence: 0.4705882352941177
#   Lift: 3.631566206729606
#   → ['milk', 'mineral water', 'spaghetti'] → ['frozen smoothie']
#   Confidence: 0.2033898305084746
#   Lift: 3.211846565566459
# --------------------------------------------------
# Rule #92: ['frozen vegetables', 'nan', 'tomatoes', 'green tea']
# Support: 0.003332888948140248
#   → ['frozen vegetables', 'green tea'] → ['nan', 'tomatoes']
#   Confidence: 0.2314814814814815
#   Lift: 3.38468341635983
#   → ['frozen vegetables', 'nan', 'green tea'] → ['tomatoes']
#   Confidence: 0.2314814814814815
#   Lift: 3.38468341635983
# --------------------------------------------------
# Rule #93: ['frozen vegetables', 'milk', 'mineral water', 'ground beef']
# Support: 0.0037328356219170776
#   → ['frozen vegetables', 'ground beef'] → ['milk', 'mineral water']
#   Confidence: 0.22047244094488186
#   Lift: 4.593788276465442
#   → ['frozen vegetables', 'mineral water', 'ground beef'] → ['milk']
#   Confidence: 0.40579710144927533
#   Lift: 3.1315679608755294
#   → ['frozen vegetables', 'milk', 'mineral water'] → ['ground beef']
#   Confidence: 0.3373493975903614
#   Lift: 3.4334570302921317
#   → ['milk', 'mineral water', 'ground beef'] → ['frozen vegetables']
#   Confidence: 0.3373493975903614
#   Lift: 3.539101861993428
# --------------------------------------------------
# Rule #94: ['frozen vegetables', 'milk', 'ground beef', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'milk', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5348837209302326
#   Lift: 3.0721001460165964
#   → ['frozen vegetables', 'milk', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3709677419354839
#   Lift: 3.7756160546242397
#   → ['milk', 'ground beef', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.3150684931506849
#   Lift: 3.305354919053549
# --------------------------------------------------
# Rule #95: ['frozen vegetables', 'mineral water', 'ground beef', 'spaghetti']
# Support: 0.004399413411545127
#   → ['frozen vegetables', 'ground beef'] → ['mineral water', 'spaghetti']
#   Confidence: 0.25984251968503935
#   Lift: 4.350622187851519
#   → ['frozen vegetables', 'mineral water', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3666666666666667
#   Lift: 3.7318407960199007
# --------------------------------------------------
# Rule #96: ['frozen vegetables', 'nan', 'ground beef', 'spaghetti']
# Support: 0.008665511265164644
#   → ['frozen vegetables', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.31100478468899523
#   Lift: 3.165328208890303
#   → ['frozen vegetables', 'nan', 'spaghetti'] → ['ground beef']
#   Confidence: 0.31100478468899523
#   Lift: 3.165328208890303
# --------------------------------------------------
# Rule #97: ['frozen vegetables', 'milk', 'mineral water', 'olive oil']
# Support: 0.003332888948140248
#   → ['frozen vegetables', 'olive oil'] → ['milk', 'mineral water']
#   Confidence: 0.29411764705882354
#   Lift: 6.12826797385621
#   → ['frozen vegetables', 'milk', 'mineral water'] → ['olive oil']
#   Confidence: 0.30120481927710846
#   Lift: 4.573557387444516
#   → ['frozen vegetables', 'mineral water', 'olive oil'] → ['milk']
#   Confidence: 0.5102040816326531
#   Lift: 3.937284790459394
#   → ['milk', 'mineral water', 'olive oil'] → ['frozen vegetables']
#   Confidence: 0.39062500000000006
#   Lift: 4.098011363636364
# --------------------------------------------------
# Rule #98: ['frozen vegetables', 'soup', 'milk', 'mineral water']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'soup'] → ['milk', 'mineral water']
#   Confidence: 0.3833333333333333
#   Lift: 7.987175925925926
#   → ['soup', 'milk'] → ['frozen vegetables', 'mineral water']
#   Confidence: 0.20175438596491227
#   Lift: 5.646864362398533
#   → ['frozen vegetables', 'milk', 'mineral water'] → ['soup']
#   Confidence: 0.27710843373493976
#   Lift: 5.484407286136631
#   → ['frozen vegetables', 'soup', 'milk'] → ['mineral water']
#   Confidence: 0.7666666666666666
#   Lift: 3.21631245339299
#   → ['frozen vegetables', 'soup', 'mineral water'] → ['milk']
#   Confidence: 0.6052631578947368
#   Lift: 4.670863114576565
#   → ['soup', 'milk', 'mineral water'] → ['frozen vegetables']
#   Confidence: 0.35937500000000006
#   Lift: 3.7701704545454553
# --------------------------------------------------
# Rule #99: ['frozen vegetables', 'milk', 'mineral water', 'spaghetti']
# Support: 0.004532728969470737
#   → ['milk', 'mineral water', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.28813559322033894
#   Lift: 3.0228043143297376
# --------------------------------------------------
# Rule #100: ['frozen vegetables', 'milk', 'nan', 'olive oil']
# Support: 0.004799360085321957
#   → ['frozen vegetables', 'milk'] → ['nan', 'olive oil']
#   Confidence: 0.20338983050847456
#   Lift: 3.094578333963626
#   → ['frozen vegetables', 'olive oil'] → ['milk', 'nan']
#   Confidence: 0.4235294117647058
#   Lift: 3.2684095860566447
#   → ['frozen vegetables', 'milk', 'nan'] → ['olive oil']
#   Confidence: 0.20338983050847456
#   Lift: 3.088314005352364
#   → ['frozen vegetables', 'nan', 'olive oil'] → ['milk']
#   Confidence: 0.4235294117647058
#   Lift: 3.2684095860566447
# --------------------------------------------------
# Rule #101: ['frozen vegetables', 'soup', 'milk', 'nan']
# Support: 0.003999466737768298
#   → ['frozen vegetables', 'soup'] → ['milk', 'nan']
#   Confidence: 0.5
#   Lift: 3.858539094650206
#   → ['frozen vegetables', 'soup', 'nan'] → ['milk']
#   Confidence: 0.5
#   Lift: 3.858539094650206
# --------------------------------------------------
# Rule #102: ['frozen vegetables', 'milk', 'tomatoes', 'nan']
# Support: 0.0041327822956939075
#   → ['milk', 'tomatoes'] → ['frozen vegetables', 'nan']
#   Confidence: 0.29523809523809524
#   Lift: 3.0973160173160172
#   → ['milk', 'tomatoes', 'nan'] → ['frozen vegetables']
#   Confidence: 0.29523809523809524
#   Lift: 3.0973160173160172
# --------------------------------------------------
# Rule #103: ['frozen vegetables', 'nan', 'shrimp', 'mineral water']
# Support: 0.007199040127982935
#   → ['shrimp', 'mineral water'] → ['frozen vegetables', 'nan']
#   Confidence: 0.30508474576271183
#   Lift: 3.200616332819722
#   → ['nan', 'shrimp', 'mineral water'] → ['frozen vegetables']
#   Confidence: 0.3068181818181818
#   Lift: 3.218801652892562
# --------------------------------------------------
# Rule #104: ['frozen vegetables', 'shrimp', 'mineral water', 'spaghetti']
# Support: 0.003332888948140248
#   → ['frozen vegetables', 'shrimp'] → ['mineral water', 'spaghetti']
#   Confidence: 0.2
#   Lift: 3.3486607142857148
#   → ['frozen vegetables', 'mineral water', 'spaghetti'] → ['shrimp']
#   Confidence: 0.2777777777777778
#   Lift: 3.8873341625207294
#   → ['shrimp', 'mineral water', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.39062500000000006
#   Lift: 4.098011363636364
# --------------------------------------------------
# Rule #105: ['frozen vegetables', 'tomatoes', 'mineral water', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'mineral water', 'spaghetti'] → ['tomatoes']
#   Confidence: 0.2555555555555556
#   Lift: 3.7366904916612524
#   → ['frozen vegetables', 'tomatoes', 'mineral water'] → ['spaghetti']
#   Confidence: 0.5227272727272727
#   Lift: 3.0022796881525826
#   → ['tomatoes', 'mineral water', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.32857142857142857
#   Lift: 3.447012987012987
# --------------------------------------------------
# Rule #106: ['frozen vegetables', 'nan', 'olive oil', 'spaghetti']
# Support: 0.005732568990801226
#   → ['frozen vegetables', 'spaghetti'] → ['nan', 'olive oil']
#   Confidence: 0.20574162679425836
#   Lift: 3.1303609383037156
#   → ['frozen vegetables', 'nan', 'spaghetti'] → ['olive oil']
#   Confidence: 0.20574162679425836
#   Lift: 3.1240241752707125
# --------------------------------------------------
# Rule #107: ['frozen vegetables', 'nan', 'shrimp', 'spaghetti']
# Support: 0.005999200106652446
#   → ['frozen vegetables', 'spaghetti'] → ['nan', 'shrimp']
#   Confidence: 0.21531100478468898
#   Lift: 3.0187810222242093
#   → ['frozen vegetables', 'nan', 'spaghetti'] → ['shrimp']
#   Confidence: 0.21531100478468898
#   Lift: 3.0131489680782684
# --------------------------------------------------
# Rule #108: ['frozen vegetables', 'nan', 'shrimp', 'tomatoes']
# Support: 0.003999466737768298
#   → ['frozen vegetables', 'shrimp'] → ['nan', 'tomatoes']
#   Confidence: 0.24000000000000002
#   Lift: 3.5092397660818717
#   → ['frozen vegetables', 'tomatoes'] → ['nan', 'shrimp']
#   Confidence: 0.2479338842975207
#   Lift: 3.4761720861975753
#   → ['shrimp', 'tomatoes'] → ['frozen vegetables', 'nan']
#   Confidence: 0.35714285714285715
#   Lift: 3.7467532467532467
#   → ['frozen vegetables', 'nan', 'shrimp'] → ['tomatoes']
#   Confidence: 0.24000000000000002
#   Lift: 3.5092397660818717
#   → ['frozen vegetables', 'nan', 'tomatoes'] → ['shrimp']
#   Confidence: 0.2479338842975207
#   Lift: 3.4696866905143704
#   → ['nan', 'shrimp', 'tomatoes'] → ['frozen vegetables']
#   Confidence: 0.35714285714285715
#   Lift: 3.7467532467532467
# --------------------------------------------------
# Rule #109: ['frozen vegetables', 'nan', 'tomatoes', 'spaghetti']
# Support: 0.006665777896280496
#   → ['frozen vegetables', 'spaghetti'] → ['nan', 'tomatoes']
#   Confidence: 0.23923444976076558
#   Lift: 3.4980460188216425
#   → ['tomatoes', 'spaghetti'] → ['frozen vegetables', 'nan']
#   Confidence: 0.3184713375796179
#   Lift: 3.341053850607991
#   → ['frozen vegetables', 'nan', 'spaghetti'] → ['tomatoes']
#   Confidence: 0.23923444976076558
#   Lift: 3.4980460188216425
#   → ['nan', 'tomatoes', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.3184713375796179
#   Lift: 3.341053850607991
# --------------------------------------------------
# Rule #110: ['grated cheese', 'nan', 'ground beef', 'spaghetti']
# Support: 0.005332622317024397
#   → ['grated cheese', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.3225806451612903
#   Lift: 3.283144395325426
#   → ['grated cheese', 'nan', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3225806451612903
#   Lift: 3.283144395325426
# --------------------------------------------------
# Rule #111: ['nan', 'tomatoes', 'ground beef', 'green tea']
# Support: 0.0030662578322890282
#   → ['ground beef', 'green tea'] → ['nan', 'tomatoes']
#   Confidence: 0.2072072072072072
#   Lift: 3.0297490472929067
#   → ['nan', 'ground beef', 'green tea'] → ['tomatoes']
#   Confidence: 0.2072072072072072
#   Lift: 3.0297490472929067
# --------------------------------------------------
# Rule #112: ['nan', 'milk', 'herb & pepper', 'ground beef']
# Support: 0.0035995200639914677
#   → ['milk', 'herb & pepper'] → ['nan', 'ground beef']
#   Confidence: 0.3913043478260869
#   Lift: 3.9825968969382335
#   → ['milk', 'herb & pepper', 'nan'] → ['ground beef']
#   Confidence: 0.3913043478260869
#   Lift: 3.9825968969382335
# --------------------------------------------------
# Rule #113: ['nan', 'mineral water', 'herb & pepper', 'ground beef']
# Support: 0.006665777896280496
#   → ['herb & pepper', 'mineral water'] → ['nan', 'ground beef']
#   Confidence: 0.39062500000000006
#   Lift: 3.975682666214383
#   → ['nan', 'herb & pepper', 'mineral water'] → ['ground beef']
#   Confidence: 0.39062500000000006
#   Lift: 3.975682666214383
# --------------------------------------------------
# Rule #114: ['nan', 'herb & pepper', 'ground beef', 'spaghetti']
# Support: 0.006399146780429276
#   → ['herb & pepper', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.3934426229508197
#   Lift: 4.004359721511667
#   → ['nan', 'herb & pepper', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3934426229508197
#   Lift: 4.004359721511667
# --------------------------------------------------
# Rule #115: ['milk', 'mineral water', 'ground beef', 'spaghetti']
# Support: 0.004399413411545127
#   → ['milk', 'ground beef'] → ['mineral water', 'spaghetti']
#   Confidence: 0.2
#   Lift: 3.3486607142857148
# --------------------------------------------------
# Rule #116: ['milk', 'nan', 'ground beef', 'olive oil']
# Support: 0.004932675643247567
#   → ['milk', 'ground beef'] → ['nan', 'olive oil']
#   Confidence: 0.22424242424242427
#   Lift: 3.4118507591124225
#   → ['milk', 'nan', 'ground beef'] → ['olive oil']
#   Confidence: 0.22424242424242427
#   Lift: 3.40494417862839
# --------------------------------------------------
# Rule #117: ['soup', 'milk', 'nan', 'ground beef']
# Support: 0.003999466737768298
#   → ['soup', 'ground beef'] → ['milk', 'nan']
#   Confidence: 0.4109589041095891
#   Lift: 3.1714019956029094
#   → ['soup', 'nan', 'ground beef'] → ['milk']
#   Confidence: 0.4109589041095891
#   Lift: 3.1714019956029094
# --------------------------------------------------
# Rule #118: ['mineral water', 'ground beef', 'olive oil', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['ground beef', 'olive oil'] → ['mineral water', 'spaghetti']
#   Confidence: 0.2169811320754717
#   Lift: 3.63298096361186
#   → ['mineral water', 'olive oil', 'spaghetti'] → ['ground beef']
#   Confidence: 0.2987012987012987
#   Lift: 3.0401064335935435
# --------------------------------------------------
# Rule #119: ['pancakes', 'mineral water', 'ground beef', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['pancakes', 'ground beef'] → ['mineral water', 'spaghetti']
#   Confidence: 0.21100917431192662
#   Lift: 3.532990661861075
# --------------------------------------------------
# Rule #120: ['tomatoes', 'mineral water', 'ground beef', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['tomatoes', 'ground beef'] → ['mineral water', 'spaghetti']
#   Confidence: 0.26136363636363635
#   Lift: 4.3760907061688314
#   → ['tomatoes', 'mineral water', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5609756097560976
#   Lift: 3.221958689724723
#   → ['tomatoes', 'mineral water', 'spaghetti'] → ['ground beef']
#   Confidence: 0.32857142857142857
#   Lift: 3.344117076952898
# --------------------------------------------------
# Rule #121: ['nan', 'pepper', 'ground beef', 'spaghetti']
# Support: 0.003332888948140248
#   → ['pepper', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.33783783783783783
#   Lift: 3.4384282518610876
#   → ['nan', 'pepper', 'spaghetti'] → ['ground beef']
#   Confidence: 0.33783783783783783
#   Lift: 3.4384282518610876
# --------------------------------------------------
# Rule #122: ['nan', 'shrimp', 'ground beef', 'spaghetti']
# Support: 0.005999200106652446
#   → ['shrimp', 'ground beef'] → ['nan', 'spaghetti']
#   Confidence: 0.5232558139534884
#   Lift: 3.005315360233627
#   → ['nan', 'shrimp', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5232558139534884
#   Lift: 3.005315360233627
# --------------------------------------------------
# Rule #123: ['nan', 'ground beef', 'tomato sauce', 'spaghetti']
# Support: 0.0030662578322890282
#   → ['tomato sauce'] → ['nan', 'ground beef', 'spaghetti']
#   Confidence: 0.2169811320754717
#   Lift: 5.535970992170453
#   → ['ground beef', 'tomato sauce'] → ['nan', 'spaghetti']
#   Confidence: 0.5750000000000001
#   Lift: 3.3025076569678413
#   → ['nan', 'tomato sauce'] → ['ground beef', 'spaghetti']
#   Confidence: 0.2169811320754717
#   Lift: 5.535970992170453
#   → ['tomato sauce', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.4893617021276596
#   Lift: 4.980599901844742
#   → ['nan', 'ground beef', 'tomato sauce'] → ['spaghetti']
#   Confidence: 0.5750000000000001
#   Lift: 3.3025076569678413
#   → ['nan', 'tomato sauce', 'spaghetti'] → ['ground beef']
#   Confidence: 0.4893617021276596
#   Lift: 4.980599901844742
# --------------------------------------------------
# Rule #124: ['light cream', 'nan', 'mineral water', 'spaghetti']
# Support: 0.003199573390214638
#   → ['light cream'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.20512820512820515
#   Lift: 3.4345238095238098
#   → ['light cream', 'nan'] → ['mineral water', 'spaghetti']
#   Confidence: 0.20512820512820515
#   Lift: 3.4345238095238098
# --------------------------------------------------
# Rule #125: ['milk', 'mineral water', 'olive oil', 'spaghetti']
# Support: 0.003332888948140248
#   → ['milk', 'mineral water', 'spaghetti'] → ['olive oil']
#   Confidence: 0.211864406779661
#   Lift: 3.216993755575379
# --------------------------------------------------
# Rule #126: ['milk', 'tomatoes', 'mineral water', 'spaghetti']
# Support: 0.003332888948140248
#   → ['milk', 'tomatoes'] → ['mineral water', 'spaghetti']
#   Confidence: 0.2380952380952381
#   Lift: 3.9865008503401365
#   → ['milk', 'mineral water', 'spaghetti'] → ['tomatoes']
#   Confidence: 0.211864406779661
#   Lift: 3.0978458387022165
# --------------------------------------------------
# Rule #127: ['milk', 'shrimp', 'nan', 'olive oil']
# Support: 0.003199573390214638
#   → ['shrimp', 'olive oil'] → ['milk', 'nan']
#   Confidence: 0.3934426229508197
#   Lift: 3.0362274843149164
#   → ['nan', 'shrimp', 'olive oil'] → ['milk']
#   Confidence: 0.39999999999999997
#   Lift: 3.0868312757201646
# --------------------------------------------------
# Rule #128: ['soup', 'milk', 'nan', 'olive oil']
# Support: 0.0035995200639914677
#   → ['milk', 'olive oil'] → ['soup', 'nan']
#   Confidence: 0.2109375
#   Lift: 4.174781497361478
#   → ['soup', 'milk'] → ['nan', 'olive oil']
#   Confidence: 0.23684210526315788
#   Lift: 3.603555033628696
#   → ['soup', 'olive oil'] → ['milk', 'nan']
#   Confidence: 0.4029850746268656
#   Lift: 3.1098673300165833
#   → ['milk', 'nan', 'olive oil'] → ['soup']
#   Confidence: 0.2109375
#   Lift: 4.174781497361478
#   → ['soup', 'milk', 'nan'] → ['olive oil']
#   Confidence: 0.23684210526315788
#   Lift: 3.5962603878116344
#   → ['soup', 'nan', 'olive oil'] → ['milk']
#   Confidence: 0.4029850746268656
#   Lift: 3.1098673300165833
# --------------------------------------------------
# Rule #129: ['milk', 'nan', 'olive oil', 'spaghetti']
# Support: 0.007199040127982935
#   → ['milk', 'spaghetti'] → ['nan', 'olive oil']
#   Confidence: 0.20300751879699247
#   Lift: 3.088761457396025
#   → ['milk', 'nan', 'spaghetti'] → ['olive oil']
#   Confidence: 0.20300751879699247
#   Lift: 3.0825089038385434
# --------------------------------------------------
# Rule #130: ['soup', 'milk', 'tomatoes', 'nan']
# Support: 0.0030662578322890282
#   → ['milk', 'tomatoes'] → ['soup', 'nan']
#   Confidence: 0.21904761904761905
#   Lift: 4.335293378565146
#   → ['soup', 'tomatoes'] → ['milk', 'nan']
#   Confidence: 0.44230769230769235
#   Lift: 3.4133230452674903
#   → ['milk', 'tomatoes', 'nan'] → ['soup']
#   Confidence: 0.21904761904761905
#   Lift: 4.335293378565146
#   → ['soup', 'nan', 'tomatoes'] → ['milk']
#   Confidence: 0.44230769230769235
#   Lift: 3.4133230452674903
# --------------------------------------------------
# Rule #131: ['whole wheat pasta', 'milk', 'nan', 'spaghetti']
# Support: 0.003999466737768298
#   → ['whole wheat pasta', 'spaghetti'] → ['milk', 'nan']
#   Confidence: 0.4545454545454546
#   Lift: 3.5077628133183696
#   → ['nan', 'whole wheat pasta', 'spaghetti'] → ['milk']
#   Confidence: 0.4545454545454546
#   Lift: 3.5077628133183696
# --------------------------------------------------
# Rule #132: ['soup', 'nan', 'mineral water', 'olive oil']
# Support: 0.005199306759098787
# ...
#   → ['frozen vegetables', 'nan', 'chocolate', 'mineral water'] → ['milk']
#   Confidence: 0.4109589041095891
#   Lift: 3.1714019956029094
# --------------------------------------------------
# Rule #141: ['frozen vegetables', 'chocolate', 'spaghetti', 'nan', 'milk']
# Support: 0.0034662045060658577
#   → ['frozen vegetables', 'chocolate', 'spaghetti'] → ['nan', 'milk']
#   Confidence: 0.44067796610169485
#   Lift: 3.4007463207086555
#   → ['milk', 'chocolate', 'spaghetti'] → ['frozen vegetables', 'nan']
#   Confidence: 0.3170731707317073
#   Lift: 3.3263858093126384
#   → ['frozen vegetables', 'nan', 'chocolate', 'spaghetti'] → ['milk']
#   Confidence: 0.44067796610169485
#   Lift: 3.4007463207086555
#   → ['milk', 'chocolate', 'nan', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.3170731707317073
#   Lift: 3.3263858093126384
# --------------------------------------------------
# Rule #142: ['frozen vegetables', 'chocolate', 'shrimp', 'mineral water', 'nan']
# Support: 0.003199573390214638
#   → ['frozen vegetables', 'chocolate', 'mineral water'] → ['nan', 'shrimp']
#   Confidence: 0.32876712328767127
#   Lift: 4.609499423889387
#   → ['chocolate', 'mineral water', 'shrimp'] → ['frozen vegetables', 'nan']
#   Confidence: 0.4210526315789474
#   Lift: 4.417224880382776
#   → ['frozen vegetables', 'nan', 'chocolate', 'mineral water'] → ['shrimp']
#   Confidence: 0.32876712328767127
#   Lift: 4.600899611531385
#   → ['nan', 'chocolate', 'mineral water', 'shrimp'] → ['frozen vegetables']
#   Confidence: 0.4210526315789474
#   Lift: 4.417224880382776
# --------------------------------------------------
# Rule #143: ['chocolate', 'olive oil', 'spaghetti', 'mineral water', 'nan']
# Support: 0.0038661511798426876
#   → ['chocolate', 'olive oil'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.23577235772357724
#   Lift: 3.947608159117306
#   → ['chocolate', 'mineral water', 'spaghetti'] → ['nan', 'olive oil']
#   Confidence: 0.2436974789915966
#   Lift: 3.707859614434008
#   → ['nan', 'chocolate', 'olive oil'] → ['mineral water', 'spaghetti']
#   Confidence: 0.23577235772357724
#   Lift: 3.947608159117306
#   → ['nan', 'chocolate', 'mineral water', 'spaghetti'] → ['olive oil']
#   Confidence: 0.2436974789915966
#   Lift: 3.700353825740822
# --------------------------------------------------
# Rule #144: ['chocolate', 'spaghetti', 'shrimp', 'mineral water', 'nan']
# Support: 0.0034662045060658577
#   → ['chocolate', 'mineral water', 'spaghetti'] → ['nan', 'shrimp']
#   Confidence: 0.21848739495798317
#   Lift: 3.063315793607162
#   → ['nan', 'chocolate', 'mineral water', 'spaghetti'] → ['shrimp']
#   Confidence: 0.21848739495798317
#   Lift: 3.0576006522011783
# --------------------------------------------------
# Rule #145: ['frozen vegetables', 'eggs', 'mineral water', 'nan', 'milk']
# Support: 0.0037328356219170776
#   → ['eggs', 'frozen vegetables', 'mineral water'] → ['nan', 'milk']
#   Confidence: 0.411764705882353
#   Lift: 3.177620430888405
#   → ['eggs', 'frozen vegetables', 'nan', 'mineral water'] → ['milk']
#   Confidence: 0.411764705882353
#   Lift: 3.177620430888405
# --------------------------------------------------
# Rule #146: ['milk', 'spaghetti', 'frozen smoothie', 'mineral water', 'nan']
# Support: 0.003199573390214638
#   → ['milk', 'frozen smoothie'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.22429906542056074
#   Lift: 3.7555073431241657
#   → ['frozen smoothie', 'spaghetti'] → ['milk', 'nan', 'mineral water']
#   Confidence: 0.20512820512820515
#   Lift: 4.274074074074075
#   → ['milk', 'frozen smoothie', 'nan'] → ['mineral water', 'spaghetti']
#   Confidence: 0.22429906542056074
#   Lift: 3.7555073431241657
#   → ['frozen smoothie', 'mineral water', 'spaghetti'] → ['milk', 'nan']
#   Confidence: 0.4705882352941177
#   Lift: 3.631566206729606
#   → ['nan', 'frozen smoothie', 'spaghetti'] → ['milk', 'mineral water']
#   Confidence: 0.20512820512820515
#   Lift: 4.274074074074075
#   → ['milk', 'mineral water', 'spaghetti'] → ['nan', 'frozen smoothie']
#   Confidence: 0.2033898305084746
#   Lift: 3.218622613173139
#   → ['nan', 'frozen smoothie', 'mineral water', 'spaghetti'] → ['milk']
#   Confidence: 0.4705882352941177
#   Lift: 3.631566206729606
#   → ['milk', 'nan', 'mineral water', 'spaghetti'] → ['frozen smoothie']
#   Confidence: 0.2033898305084746
#   Lift: 3.211846565566459
# --------------------------------------------------
# Rule #147: ['frozen vegetables', 'milk', 'mineral water', 'ground beef', 'nan']
# Support: 0.0037328356219170776
#   → ['frozen vegetables', 'ground beef'] → ['milk', 'nan', 'mineral water']
#   Confidence: 0.22047244094488186
#   Lift: 4.593788276465442
#   → ['frozen vegetables', 'mineral water', 'ground beef'] → ['milk', 'nan']
#   Confidence: 0.40579710144927533
#   Lift: 3.1315679608755294
#   → ['frozen vegetables', 'nan', 'ground beef'] → ['milk', 'mineral water']
#   Confidence: 0.22047244094488186
#   Lift: 4.593788276465442
#   → ['frozen vegetables', 'milk', 'mineral water'] → ['nan', 'ground beef']
#   Confidence: 0.3373493975903614
#   Lift: 3.4334570302921317
#   → ['milk', 'mineral water', 'ground beef'] → ['frozen vegetables', 'nan']
#   Confidence: 0.3373493975903614
#   Lift: 3.539101861993428
#   → ['frozen vegetables', 'nan', 'mineral water', 'ground beef'] → ['milk']
#   Confidence: 0.40579710144927533
#   Lift: 3.1315679608755294
#   → ['frozen vegetables', 'milk', 'nan', 'mineral water'] → ['ground beef']
#   Confidence: 0.3373493975903614
#   Lift: 3.4334570302921317
#   → ['nan', 'milk', 'mineral water', 'ground beef'] → ['frozen vegetables']
#   Confidence: 0.3373493975903614
#   Lift: 3.539101861993428
# --------------------------------------------------
# Rule #148: ['frozen vegetables', 'spaghetti', 'nan', 'ground beef', 'milk']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'milk', 'ground beef'] → ['nan', 'spaghetti']
#   Confidence: 0.5348837209302326
#   Lift: 3.0721001460165964
#   → ['frozen vegetables', 'milk', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.3709677419354839
#   Lift: 3.7756160546242397
#   → ['milk', 'ground beef', 'spaghetti'] → ['frozen vegetables', 'nan']
#   Confidence: 0.3150684931506849
#   Lift: 3.305354919053549
#   → ['frozen vegetables', 'milk', 'nan', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5348837209302326
#   Lift: 3.0721001460165964
#   → ['frozen vegetables', 'milk', 'nan', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3709677419354839
#   Lift: 3.7756160546242397
#   → ['milk', 'nan', 'ground beef', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.3150684931506849
#   Lift: 3.305354919053549
# --------------------------------------------------
# Rule #149: ['frozen vegetables', 'spaghetti', 'mineral water', 'ground beef', 'nan']
# Support: 0.004399413411545127
#   → ['frozen vegetables', 'ground beef'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.25984251968503935
#   Lift: 4.350622187851519
#   → ['frozen vegetables', 'nan', 'ground beef'] → ['mineral water', 'spaghetti']
#   Confidence: 0.25984251968503935
#   Lift: 4.350622187851519
#   → ['frozen vegetables', 'mineral water', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.3666666666666667
#   Lift: 3.7318407960199007
#   → ['frozen vegetables', 'nan', 'mineral water', 'spaghetti'] → ['ground beef']
#   Confidence: 0.3666666666666667
#   Lift: 3.7318407960199007
# --------------------------------------------------
# Rule #150: ['frozen vegetables', 'olive oil', 'mineral water', 'nan', 'milk']
# Support: 0.003332888948140248
#   → ['frozen vegetables', 'olive oil'] → ['nan', 'mineral water', 'milk']
#   Confidence: 0.29411764705882354
#   Lift: 6.12826797385621
#   → ['frozen vegetables', 'milk', 'mineral water'] → ['nan', 'olive oil']
#   Confidence: 0.30120481927710846
#   Lift: 4.582834380116816
#   → ['frozen vegetables', 'mineral water', 'olive oil'] → ['nan', 'milk']
#   Confidence: 0.5102040816326531
#   Lift: 3.937284790459394
#   → ['frozen vegetables', 'nan', 'olive oil'] → ['milk', 'mineral water']
#   Confidence: 0.29411764705882354
#   Lift: 6.12826797385621
#   → ['milk', 'mineral water', 'olive oil'] → ['frozen vegetables', 'nan']
#   Confidence: 0.39062500000000006
#   Lift: 4.098011363636364
#   → ['frozen vegetables', 'milk', 'nan', 'mineral water'] → ['olive oil']
#   Confidence: 0.30120481927710846
#   Lift: 4.573557387444516
#   → ['frozen vegetables', 'nan', 'mineral water', 'olive oil'] → ['milk']
#   Confidence: 0.5102040816326531
#   Lift: 3.937284790459394
#   → ['milk', 'nan', 'mineral water', 'olive oil'] → ['frozen vegetables']
#   Confidence: 0.39062500000000006
#   Lift: 4.098011363636364
# --------------------------------------------------
# Rule #151: ['frozen vegetables', 'mineral water', 'soup', 'nan', 'milk']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'soup'] → ['nan', 'mineral water', 'milk']
#   Confidence: 0.3833333333333333
#   Lift: 7.987175925925926
#   → ['soup', 'milk'] → ['frozen vegetables', 'nan', 'mineral water']
#   Confidence: 0.20175438596491227
#   Lift: 5.646864362398533
#   → ['frozen vegetables', 'milk', 'mineral water'] → ['soup', 'nan']
#   Confidence: 0.27710843373493976
#   Lift: 5.484407286136631
#   → ['frozen vegetables', 'soup', 'milk'] → ['nan', 'mineral water']
#   Confidence: 0.7666666666666666
#   Lift: 3.218112292482745
#   → ['frozen vegetables', 'soup', 'mineral water'] → ['nan', 'milk']
#   Confidence: 0.6052631578947368
#   Lift: 4.670863114576565
#   → ['frozen vegetables', 'soup', 'nan'] → ['milk', 'mineral water']
#   Confidence: 0.3833333333333333
#   Lift: 7.987175925925926
#   → ['soup', 'milk', 'mineral water'] → ['frozen vegetables', 'nan']
#   Confidence: 0.35937500000000006
#   Lift: 3.7701704545454553
#   → ['soup', 'milk', 'nan'] → ['frozen vegetables', 'mineral water']
#   Confidence: 0.20175438596491227
#   Lift: 5.646864362398533
#   → ['frozen vegetables', 'milk', 'nan', 'mineral water'] → ['soup']
#   Confidence: 0.27710843373493976
#   Lift: 5.484407286136631
#   → ['frozen vegetables', 'soup', 'milk', 'nan'] → ['mineral water']
#   Confidence: 0.7666666666666666
#   Lift: 3.21631245339299
#   → ['frozen vegetables', 'soup', 'nan', 'mineral water'] → ['milk']
#   Confidence: 0.6052631578947368
#   Lift: 4.670863114576565
#   → ['soup', 'milk', 'nan', 'mineral water'] → ['frozen vegetables']
#   Confidence: 0.35937500000000006
#   Lift: 3.7701704545454553
# --------------------------------------------------
# Rule #152: ['frozen vegetables', 'spaghetti', 'mineral water', 'nan', 'milk']
# Support: 0.004532728969470737
#   → ['milk', 'mineral water', 'spaghetti'] → ['frozen vegetables', 'nan']
#   Confidence: 0.28813559322033894
#   Lift: 3.0228043143297376
#   → ['milk', 'nan', 'mineral water', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.28813559322033894
#   Lift: 3.0228043143297376
# --------------------------------------------------
# Rule #153: ['frozen vegetables', 'spaghetti', 'shrimp', 'mineral water', 'nan']
# Support: 0.003332888948140248
#   → ['frozen vegetables', 'shrimp'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.2
#   Lift: 3.3486607142857148
#   → ['frozen vegetables', 'mineral water', 'spaghetti'] → ['nan', 'shrimp']
#   Confidence: 0.2777777777777778
#   Lift: 3.89460020768432
#   → ['frozen vegetables', 'nan', 'shrimp'] → ['mineral water', 'spaghetti']
#   Confidence: 0.2
#   Lift: 3.3486607142857148
#   → ['shrimp', 'mineral water', 'spaghetti'] → ['frozen vegetables', 'nan']
#   Confidence: 0.39062500000000006
#   Lift: 4.098011363636364
#   → ['frozen vegetables', 'nan', 'mineral water', 'spaghetti'] → ['shrimp']
#   Confidence: 0.2777777777777778
#   Lift: 3.8873341625207294
#   → ['nan', 'shrimp', 'mineral water', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.39062500000000006
#   Lift: 4.098011363636364
# --------------------------------------------------
# Rule #154: ['frozen vegetables', 'spaghetti', 'tomatoes', 'mineral water', 'nan']
# Support: 0.0030662578322890282
#   → ['frozen vegetables', 'mineral water', 'spaghetti'] → ['nan', 'tomatoes']
#   Confidence: 0.2555555555555556
#   Lift: 3.7366904916612524
#   → ['frozen vegetables', 'tomatoes', 'mineral water'] → ['nan', 'spaghetti']
#   Confidence: 0.5227272727272727
#   Lift: 3.0022796881525826
#   → ['tomatoes', 'mineral water', 'spaghetti'] → ['frozen vegetables', 'nan']
#   Confidence: 0.32857142857142857
#   Lift: 3.447012987012987
#   → ['frozen vegetables', 'nan', 'mineral water', 'spaghetti'] → ['tomatoes']
#   Confidence: 0.2555555555555556
#   Lift: 3.7366904916612524
#   → ['frozen vegetables', 'nan', 'tomatoes', 'mineral water'] → ['spaghetti']
#   Confidence: 0.5227272727272727
#   Lift: 3.0022796881525826
#   → ['nan', 'tomatoes', 'mineral water', 'spaghetti'] → ['frozen vegetables']
#   Confidence: 0.32857142857142857
#   Lift: 3.447012987012987
# --------------------------------------------------
# Rule #155: ['milk', 'spaghetti', 'mineral water', 'ground beef', 'nan']
# Support: 0.004399413411545127
#   → ['milk', 'ground beef'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.2
#   Lift: 3.3486607142857148
#   → ['milk', 'nan', 'ground beef'] → ['mineral water', 'spaghetti']
#   Confidence: 0.2
#   Lift: 3.3486607142857148
# --------------------------------------------------
# Rule #156: ['olive oil', 'spaghetti', 'mineral water', 'ground beef', 'nan']
# Support: 0.0030662578322890282
#   → ['ground beef', 'olive oil'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.2169811320754717
#   Lift: 3.63298096361186
#   → ['nan', 'ground beef', 'olive oil'] → ['mineral water', 'spaghetti']
#   Confidence: 0.2169811320754717
#   Lift: 3.63298096361186
#   → ['mineral water', 'olive oil', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.2987012987012987
#   Lift: 3.0401064335935435
#   → ['nan', 'mineral water', 'olive oil', 'spaghetti'] → ['ground beef']
#   Confidence: 0.2987012987012987
#   Lift: 3.0401064335935435
# --------------------------------------------------
# Rule #157: ['spaghetti', 'mineral water', 'pancakes', 'ground beef', 'nan']
# Support: 0.0030662578322890282
#   → ['pancakes', 'ground beef'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.21100917431192662
#   Lift: 3.532990661861075
#   → ['pancakes', 'nan', 'ground beef'] → ['mineral water', 'spaghetti']
#   Confidence: 0.21100917431192662
#   Lift: 3.532990661861075
# --------------------------------------------------
# Rule #158: ['spaghetti', 'tomatoes', 'mineral water', 'ground beef', 'nan']
# Support: 0.0030662578322890282
#   → ['tomatoes', 'ground beef'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.26136363636363635
#   Lift: 4.3760907061688314
#   → ['tomatoes', 'mineral water', 'ground beef'] → ['nan', 'spaghetti']
#   Confidence: 0.5609756097560976
#   Lift: 3.221958689724723
#   → ['nan', 'tomatoes', 'ground beef'] → ['mineral water', 'spaghetti']
#   Confidence: 0.26136363636363635
#   Lift: 4.3760907061688314
#   → ['tomatoes', 'mineral water', 'spaghetti'] → ['nan', 'ground beef']
#   Confidence: 0.32857142857142857
#   Lift: 3.344117076952898
#   → ['tomatoes', 'nan', 'mineral water', 'ground beef'] → ['spaghetti']
#   Confidence: 0.5609756097560976
#   Lift: 3.221958689724723
#   → ['nan', 'tomatoes', 'mineral water', 'spaghetti'] → ['ground beef']
#   Confidence: 0.32857142857142857
#   Lift: 3.344117076952898
# --------------------------------------------------
# Rule #159: ['olive oil', 'spaghetti', 'mineral water', 'nan', 'milk']
# Support: 0.003332888948140248
#   → ['milk', 'mineral water', 'spaghetti'] → ['nan', 'olive oil']
#   Confidence: 0.211864406779661
#   Lift: 3.223519097878777
#   → ['milk', 'nan', 'mineral water', 'spaghetti'] → ['olive oil']
#   Confidence: 0.211864406779661
#   Lift: 3.216993755575379
# --------------------------------------------------
# Rule #160: ['spaghetti', 'tomatoes', 'mineral water', 'nan', 'milk']
# Support: 0.003332888948140248
#   → ['milk', 'tomatoes'] → ['nan', 'mineral water', 'spaghetti']
#   Confidence: 0.2380952380952381
#   Lift: 3.9865008503401365
#   → ['milk', 'mineral water', 'spaghetti'] → ['nan', 'tomatoes']
#   Confidence: 0.211864406779661
#   Lift: 3.0978458387022165
#   → ['milk', 'tomatoes', 'nan'] → ['mineral water', 'spaghetti']
#   Confidence: 0.2380952380952381
#   Lift: 3.9865008503401365
#   → ['milk', 'nan', 'mineral water', 'spaghetti'] → ['tomatoes']
#   Confidence: 0.211864406779661
#   Lift: 3.0978458387022165
# --------------------------------------------------
